# %% [markdown]
# <a href="https://colab.research.google.com/github/kuwarbimal/Math-Computer-Learning/blob/main/CatalogofSpecialCurvesipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# important python libaries for graphing
import numpy as np
import matplotlib.pyplot as plt

# %%
#plot absolute value function as numpy absolute = np.absolute
x = np.linspace(-10, 10, 101)
plt.plot(x, np.absolute(x))
plt.show()

# %%
# setting the axes projection as polar
plt.axes(projection = 'polar')
  
# setting the radius
r = 2
  
# creating an array containing the
# radian values
rads = np.arange(0, (2 * np.pi), 0.01)
  
# plotting the circle
for rad in rads:
    plt.polar(rad, r, 'g.')
  
# display the Polar plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
  
  
# setting the axes
# projection as polar
plt.axes(projection = 'polar')
  
# setting the values of
# semi-major and
# semi-minor axes
a = 4
b = 3
  
# creating an array
# containing the radian values
rads = np.arange(0, (2 * np.pi), 0.01)
  
# plotting the ellipse
for rad in rads:
    r = (a*b)/math.sqrt((a*np.sin(rad))**2 + (b*np.cos(rad))**2)
    plt.polar(rad, r, 'g.')
  
# display the polar plot
plt.show()

# %% [markdown]
# # Cardoid
# This is the curve described by a point $P$ of a circle of radius $a$ as it rolls on the outside of a fixed cricle of radius $a$. This curve is a special case of a limacon

# %%
import math
  
  
# setting the axes
# projection as polar
plt.axes(projection = 'polar')
  
# setting the length of 
# axis of cardioid
a=4
  
# creating an array
# containing the radian values
rads = np.arange(0, (2 * np.pi), 0.01)
   
# plotting the cardioid
for rad in rads:
    r = a + (a*np.cos(rad)) 
    plt.polar(rad,r,'g.') 
  
# display the polar plot
plt.show()

# %% [markdown]
# # Sprial of Archimedes

# %%
# setting the axes
# projection as polar
plt.axes(projection = 'polar')
  
# creating an array
# containing the radian values
rads = np.arange(0, 2 * np.pi, 0.001) 
  
# plotting the spiral
for rad in rads:
    r = rad
    plt.polar(rad, r, 'g.')
      
# display the polar plot
plt.show()

# %%
# setting the axes
# projection as polar
plt.axes(projection='polar')
  
# setting the length
# and number of petals
a = 1
n = 6
  
# creating an array
# containing the radian values
rads = np.arange(0, 2 * np.pi, 0.001) 
  
# plotting the rose
for rad in rads:
    r = a * np.cos(n*rad)
    plt.polar(rad, r, 'g.')
   
# display the polar plot
plt.show()

# %%
# setting the axes
# projection as polar
plt.axes(projection='polar')
  
# setting the length
# and number of petals
a = 12
n = 1
  
# creating an array
# containing the radian values
rads = np.arange(0, np.pi, 0.001) 
  
# plotting the rose
for rad in rads:
    r = a * np.sin(n*rad)*np.cos(n*rad)*np.cos(n*rad)
    plt.polar(rad, r, 'g.')
   
# display the polar plot
plt.show()

# %% [markdown]
# An asteroid is formed by rolling a circle of radius r/4 inside a circle of radius r and tracing the path of a point on the smaller circle.

# %%
# Creating vectors X and Y
x = np.linspace(-2, 2, 100)
y = (4-x**(2/3))**(3/2)
  
fig = plt.figure(figsize = (10, 5))
# Create the plot
plt.plot(x, y)
  
# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in power
#   This is separate from the ipykernel package so we can avoid doing imports until
