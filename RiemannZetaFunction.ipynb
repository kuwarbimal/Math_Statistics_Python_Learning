# %% [markdown]
# <a href="https://colab.research.google.com/github/kuwarbimal/Math-Computer-Learning/blob/main/RiemannZetaFunction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cmath

# %% [markdown]
# ELias M. Stein and Rami Shakaarchi " It is no exaggeraton to say that the gamma and zeta functions are among the most imprortant nonelemenatary functions in mathematics. The gamma function $\Gamma$ is ubiquitous in natures" **The Riemanna zeta function** is intially defined for real $s>1$ by the following convergent series $ \zeta(s)= \sum_{i=0}^\infty \frac{1}{n^s}.$

# %% [markdown]
# The zeta function $\zeta$ can be continued into the complex plane.The series defining $\zeta(s)$ converges for $Re(s)>1$, and the function $\zeta$ is holomorphic (analytic/regular/complex-differentiable) in this half plane.

# %%
# Eventhough the orginial zeta function is defined for infinte sum, we add only finite terms up to num_iters
def zeta(s, num_iters=50):
  arr= []
  # initalize complex number value
  sum_value = 0+0j
  # define riemann zeta function
  for i in range(0, num_iters):
    den =  (i+1)**s
    term = (1 + 0j)/den
    sum_value += term
    #store all the sum values
    arr.append(sum_value)
  
  # extract real parts and imaginary part of complex number and plot them.
  reals = [x.real for x in arr]
  imags = [x.imag for x in arr]
  plt.plot(reals, imags)
  return sum_value
# if the graph spirals, it means the riemman sum is trying to converge.
zeta(0.5+986.764j, 50000)
# Out:
# (0.1958915357170225+0.023581914512160605j)

# %%
zeta(0.5, 50)
# Out:
# (12.752373944855652+0j)

# %%
zeta(-1, 100)
# Out:
# (5050+0j)
